# %%
import pandas as pd

# %%
df = pd.read_csv("neighborhood_market_tracker.tsv000" ,sep='\t', usecols=['region',
       'city', 'state', 'state_code','parent_metro_region', 'parent_metro_region_metro_code'])

# %%
df_il = df[(df["state_code"] == "IL") & (df["city"] == "Chicago")]

# %%
df_il['region'].unique()
# Out:
# array(['Chicago, IL - Logan Square', 'Chicago, IL - Bucktown',
#        'Chicago, IL - North Lawndale', 'Chicago, IL - Andersonville',
#        'Chicago, IL - Avalon Park', 'Chicago, IL - West Lawn',
#        'Chicago, IL - Cragin', 'Chicago, IL - Midway Park',
#        'Chicago, IL - Morgan Park', 'Chicago, IL - River West',
#        'Chicago, IL - South Loop', 'Chicago, IL - Hanson Park',
#        'Chicago, IL - North Austin', 'Chicago, IL - Noble Square',
#        'Chicago, IL - Uptown', 'Chicago, IL - Grand Crossing',
#        'Chicago, IL - The Bush', 'Chicago, IL - Groveland Park',
#        'Chicago, IL - Sheffield', 'Chicago, IL - Lithuanian Downtown',
#        'Chicago, IL - Schorsch Forest View',
#        'Chicago, IL - New East Side', 'Chicago, IL - Humboldt Park',
#        'Chicago, IL - South Old Irving Park', 'Chicago, IL - Oakland',
#        'Chicago, IL - Horner Park', 'Chicago, IL - Stony Island Park',
# ...
